# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creating a dataset of visitors
data = {
    'Visitor_ID': [f'V{1000 + i}' for i in range(20)],
    'Name': ['GAYATRI SURESH GAIKWAD','ABHISHEK SANDEEP ZADE ', 'ARNAV AJAY DESHPANDE.. ', '.. .. ASHWINI LALCHAND MUNDAWARE/ ', 'HARSHADA GANESH CHAUDHARI', 'VAIBHAVI HARISHWAR PATIL', np.nan, 'VISHAKHA PUNDLIK JADHAV', 'YASH BHARAT SOLUNKE/', 'VIVEK SANTOSH KHANDWE', 'VISHAKHA PUNDLIK JADHAV', 'Tanushree chhanwal', 'Shruti jaiswal', 'Shriyash Sulakhe', 'YASH BHARAT SOLUNKE', np.nan, 'ARNAV AJAY DESHPANDE', 'RUTUJA SANTOSH THOTE', 'ROHIT DILIP BILWAL', 'RITESH SHIVAJI BAIRAGI'],
    'Age': [25, 23, 22, np.nan, 21, 25, 24, 24, 28, np.nan, 22, 23, 25, 27, 25, 30, 31, 26, 19, 19],
    'Ticket_Price': [500, 750, 500, 1000, np.nan, 500, 700, 650, 750, 1000, 500, 800, np.nan, 750, 500, 700, 900, 850, 750, np.nan],
    'Check_In_Time': ['10:00 AM', '10:30 AM', '11:00 AM', '11:30 AM', np.nan, '10:00 AM', '12:00 PM', '12:30 PM', '01:00 PM', '01:30 PM', '11:00 AM', '02:00 PM', np.nan, '02:30 PM', '10:00 AM', '12:00 PM', '03:00 PM', '03:30 PM', '04:00 PM', np.nan],
    'City':['Delhi','Aurangabad', 'Mumbai','Bombay','New Delhi','NDL','Chennai','Chenai','Chennaai','Bangalore', 'Delhi','Pune', 'New Delhi','Bombay','New Delhi','NDL','Indore','Bangalore','Ujjain','Bangalore'],
    'State': ['Delhi','Maharastra', 'Maharastra','Maharastra','Delhi','Delhi','Tamilnadu','Tamilnadu','Tamilnadu','Karnataka', 'Delhi','Maharastra', 'Delhi','Maharastra','Delhi','Delhi','Madhya Pradesh','Karnataka','Madhya Pradesh','Karnataka']
}

# Convert it into pandas dataframe
df = pd.DataFrame(data)

# Print size of dataframe
print("Size of DataFrame: ", df.shape)

# Print top 5 and last 2 rows
print("Top 5 Rows:")
print(df.head(5))
print("\nLast 2 Rows:")
print(df.tail(2))

# Print column data types
print("\nColumn Data Types:")
print(df.dtypes)

# Print statistical descriptions
print("\nStatistical Descriptions:")
print(df.describe())

# Do data cleaning preprocessing like remove special characters like .., / from Names
df['Name'] = df['Name'].str.replace('..', '').str.replace('/', '')

# Handle blank data
df['Name'] = df['Name'].fillna('Unknown')
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Ticket_Price'] = df['Ticket_Price'].fillna(df['Ticket_Price'].median())
df['Check_In_Time'] = df['Check_In_Time'].fillna('Unknown')

# Remove duplicates
df = df.drop_duplicates()

print("\nCleaned DataFrame:")
print(df)

# 1. Plot the number of visitors over different days (Line Plot)
plt.figure(figsize=(10, 6))
plt.plot(df['Visitor_ID'], df['Age'], marker='o')
plt.title('Number of Visitors Over Different Days')
plt.xlabel('Visitor ID')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Size of DataFrame:  (20, 7)
# Top 5 Rows:
#   Visitor_ID                                Name   Age  Ticket_Price  \
# 0      V1000              GAYATRI SURESH GAIKWAD  25.0         500.0
# 1      V1001              ABHISHEK SANDEEP ZADE   23.0         750.0
# 2      V1002             ARNAV AJAY DESHPANDE..   22.0         500.0
# 3      V1003  .. .. ASHWINI LALCHAND MUNDAWARE/    NaN        1000.0
# 4      V1004           HARSHADA GANESH CHAUDHARI  21.0           NaN
#
#   Check_In_Time        City       State
# 0      10:00 AM       Delhi       Delhi
# 1      10:30 AM  Aurangabad  Maharastra
# 2      11:00 AM      Mumbai  Maharastra
# 3      11:30 AM      Bombay  Maharastra
# 4           NaN   New Delhi       Delhi
#
# Last 2 Rows:
#    Visitor_ID                    Name   Age  Ticket_Price Check_In_Time  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creating a dataset of visitors
data = {
    'Visitor_ID': [f'V{1000 + i}' for i in range(20)],
    'Name': ['GAYATRI SURESH GAIKWAD','ABHISHEK SANDEEP ZADE ', 'ARNAV AJAY DESHPANDE.. ', '.. .. ASHWINI LALCHAND MUNDAWARE/ ', 'HARSHADA GANESH CHAUDHARI', 'VAIBHAVI HARISHWAR PATIL', np.nan, 'VISHAKHA PUNDLIK JADHAV', 'YASH BHARAT SOLUNKE/', 'VIVEK SANTOSH KHANDWE', 'VISHAKHA PUNDLIK JADHAV', 'Tanushree chhanwal', 'Shruti jaiswal', 'Shriyash Sulakhe', 'YASH BHARAT SOLUNKE', np.nan, 'ARNAV AJAY DESHPANDE', 'RUTUJA SANTOSH THOTE', 'ROHIT DILIP BILWAL', 'RITESH SHIVAJI BAIRAGI'],
    'Age': [25, 23, 22, np.nan, 21, 25, 24, 24, 28, np.nan, 22, 23, 25, 27, 25, 30, 31, 26, 19, 19],
    'Ticket_Price': [500, 750, 500, 1000, np.nan, 500, 700, 650, 750, 1000, 500, 800, np.nan, 750, 500, 700, 900, 850, 750, np.nan],
    'Check_In_Time': ['10:00 AM', '10:30 AM', '11:00 AM', '11:30 AM', np.nan, '10:00 AM', '12:00 PM', '12:30 PM', '01:00 PM', '01:30 PM', '11:00 AM', '02:00 PM', np.nan, '02:30 PM', '10:00 AM', '12:00 PM', '03:00 PM', '03:30 PM', '04:00 PM', np.nan],
    'City':['Delhi','Aurangabad', 'Mumbai','Bombay','New Delhi','NDL','Chennai','Chenai','Chennaai','Bangalore', 'Delhi','Pune', 'New Delhi','Bombay','New Delhi','NDL','Indore','Bangalore','Ujjain','Bangalore'],
    'State': ['Delhi','Maharastra', 'Maharastra','Maharastra','Delhi','Delhi','Tamilnadu','Tamilnadu','Tamilnadu','Karnataka', 'Delhi','Maharastra', 'Delhi','Maharastra','Delhi','Delhi','Madhya Pradesh','Karnataka','Madhya Pradesh','Karnataka']
}

# Convert it into pandas dataframe
df = pd.DataFrame(data)

# Print size of dataframe
print("Size of DataFrame: ", df.shape)

# Print top 5 and last 2 rows
print("Top 5 Rows:")
print(df.head(5))
print("\nLast 2 Rows:")
print(df.tail(2))

# Print column data types
print("\nColumn Data Types:")
print(df.dtypes)

# Print statistical descriptions
print("\nStatistical Descriptions:")
print(df.describe())

# Do data cleaning preprocessing like remove special characters like .., / from Names
df['Name'] = df['Name'].str.replace('..', '').str.replace('/', '')

# Handle blank data
df['Name'] = df['Name'].fillna('Unknown')
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Ticket_Price'] = df['Ticket_Price'].fillna(df['Ticket_Price'].median())
df['Check_In_Time'] = df['Check_In_Time'].fillna('Unknown')

# Remove duplicates
df = df.drop_duplicates()

print("\nCleaned DataFrame:")
print(df)

# 1. Plot the number of visitors over different days (Line Plot)
plt.figure(figsize=(10, 6))
plt.plot(df['Visitor_ID'], df['Age'], marker='o')
plt.title('Number of Visitors Over Different Days')
plt.xlabel('Visitor ID')
plt.ylabel('Age')
# Out:
# Size of DataFrame:  (20, 7)
# Top 5 Rows:
#   Visitor_ID                                Name   Age  Ticket_Price  \
# 0      V1000              GAYATRI SURESH GAIKWAD  25.0         500.0
# 1      V1001              ABHISHEK SANDEEP ZADE   23.0         750.0
# 2      V1002             ARNAV AJAY DESHPANDE..   22.0         500.0
# 3      V1003  .. .. ASHWINI LALCHAND MUNDAWARE/    NaN        1000.0
# 4      V1004           HARSHADA GANESH CHAUDHARI  21.0           NaN
#
#   Check_In_Time        City       State
# 0      10:00 AM       Delhi       Delhi
# 1      10:30 AM  Aurangabad  Maharastra
# 2      11:00 AM      Mumbai  Maharastra
# 3      11:30 AM      Bombay  Maharastra
# 4           NaN   New Delhi       Delhi
#
# Last 2 Rows:
#    Visitor_ID                    Name   Age  Ticket_Price Check_In_Time  \
# 18      V1018      ROHIT DILIP BILWAL  19.0         750.0      04:00 PM
# 19      V1019  RITESH SHIVAJI BAIRAGI  19.0           NaN           NaN
#
# ...
